# %% [markdown]
# The following notebook is to plan goals and milestones towards the completion of the final project.<br><br>
#
# Due date:<br>
# Thursday, December 11th, 2025
# <br><br>
# Soft due date:
# Sunday, December 7th, 2025 <i>Revised soft due date, sometime in the AM of Monday, December 8th, 2025.</i>
# <br><br>
# Goals and Milestones:
# 1. Saturday, November 29th, 2025 - Dataset Research and Exploratory Analysis
# 2. Sunday, November 30th, 2025 - Dataset Approval Submission <i>deadline extended to Tuesday, December 2nd, 2025</i>
# 3. Tuesday, December 2nd, 2025 - Phase 1: Feature Engineering <i>deadline extended to Tuesday, December 4th, 2025</i>
# 4. Friday, December 5th, 2025 - Phase 2: Predictive Model Building
# 5. Saturday, December 6th, 2025 - Video <i>Revised soft due date, sometime in the AM of Monday, December 8th, 2025.</i>
# 6. Sunday, December 7th, 2025 - Review and Editing <i>Revised soft due date, sometime in the AM of Monday, December 8th, 2025.</i>

# %% [markdown]
# <h4>Project Goal: Predict what type of power plant a geographic location might have based on geographic variables.</h4>
#
#
# dataset | selected | validated
#
# 1. albedo and sunlight | [x] [x] https://www.ecmwf.int/en/era5-land google-cloud-sdk
# 2. precipitation [x] [x] https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/
# 3. rivers and estuaries [x] [x] cartopy
# 4. distance from coastline [x] [x] cartopy
# 7. wind [x] [x] https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/
# 8. terrain [x] [x] https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/
# 9. relative humidity [x] [x] https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/
# 10. power plants [x] [x] https://www.kaggle.com/datasets/jaytilala/global-power-plant
#
#
# Submit dataset proposal by 11:59:59 PM, November 30th.<br>
# *Deadline extension 11:59:59 PM, December 2nd.

# %% [markdown]
# Important to remember:<br>
# correlation does not equal causation

# %% [markdown]
# Some other potential data sources if time allows could be:<br>
# 1. seismic data
# 2. natural disasters
# 3. locations of data centers
#
# I want to keep it to geography and natural stuff. I considered roads, bridges, and existing infrastructure; however, the goal is to build something that predicts expected power output of a power plant based on geographic considerations. Or at least, to predict something about power plants based on geography.

# %% [markdown]
# <h2>Feature Discovery Using Unsupervised Learning</h2>

# %% [markdown]
# <h3>Step 1: Data Cleaning & EDA</h3>

# %% [markdown]
# 1. Document at least 5 data quality issues you found and how you fixed them
# 2. Create at least 4-6 visualizations showing distributions, relationships, and potential patterns (aim for 6+ for excellent work)
# 3. Explain what you notice in plain language

# %% [markdown]
# <h3>Data quality issues</h3>

# %% [markdown]
# 1. had to use atmospheric data vs. land data
# 2. had to use 2018-2020 time frame rather than 2024-2025 <----- have to mention this, global temperatures have changed, the approximation is .21 degC per decade. It's not much, but remarkable.
# 3. Many of the geographic and atmospheric datasets have values derived from the population dataset's [LONG] and [LAT] coordinates. I had to round the coordinates to -5 decimal points to merge both datasets together. (is this a data quality issue?)
# 4. there is a discrepancy between the kontur dataset and several global population estimates
# 5. Over a third of the data points when a merge between the atmospheric dataset and the combined population and power plant dataset is missing. There are only about 12k stations in the NCEI database. There are approximately 30k power plants. A higher resolution can allow us to extrapolate what atmospheric patterns might be; however, a more rigoroues approach might be appropriate. (is this even a data quality issue if the solution is to use a different function?)meh, I'd skip it.
# 6. Skipped the above data issue. There are many missing values in the atmospheric dataset. The solution is to replace the missing values that are delineated by 999.9 or 9999.9 with np.nan. Except with the precipitation. Sometimes, 99.99 is used to delineate days where 0 precipitation fell. 0 should contribute to the average, so, should be interesting to manage.
# 7. dataset_exploration_precipitation_monthly, download all years, not just [2024,2025]
# 8. verify temperature data from google sdk and ncei dataset
# 9. Cowlitz River and Mayfield Dam and similar errors in the distance to water calculations.
# 10.

# %% [markdown]
# <h3>Complete Dataset</h3>

# %% [markdown]
# 1. albedo and sunlight [x] <i>add albedo if time permits.</i>
# 2. precipitation [x]
# 3. rivers and estuaries [x]
# 4. distance from coastline [x]
# 5. existing infrastructure [ ]
# 6. population [x]
# 7. wind [x]
# 8. terrain [x]
# 9. relative humidity [x]
# 10. power plants [x]

# %% [markdown]
# <h3>Step 2: Unsupervised Feature Discovery</h3>

# %% [markdown]
# Use unsupervised learning to discover features that will improve your predictions. You must complete ONE of these (you may do both if you wish, but must fully complete at least one):
#
# Option A: Clustering
# Try at least 3-4 different values of k (e.g., k=2, 3, 4, 5) and use the elbow method or silhouette scores to select the optimal number
# Use the elbow method or silhouette scores to help decide
# Minimum 4 visualizations required:
#
# Elbow plot or silhouette plot
# Scatter plot showing your final clusters (color-coded)
# At least 2 additional visualizations comparing clusters (box plots, bar charts, heatmaps showing cluster characteristics)
# Describe each cluster: What makes this group different? Give them meaningful names that reflect their characteristics. Think ahead: How might cluster membership help you predict your target variable in Phase 2?
#
# Examples of good cluster names:
#
# ✅ "Budget-conscious families" (not "Cluster 1")<br>
# ✅ "Premium business travelers" (not "High-value customers")<br>
# ✅ "Occasional weekend shoppers" (not "Low-frequency segment")<br>
# Examples of poor cluster names:<br>
#
# ❌ "Cluster 1", "Cluster 2"<br>
# ❌ "High-value customers" (too generic)<br>
# ❌ "Group A" (not descriptive)<br>
#
# Option B: PCA (Principal Component Analysis)<br>
# Reduce your features to find the main patterns<br>
# Show how much variance each component explains<br>
# Minimum 4 visualizations required:<br>
#
# Scree plot (variance explained)
# Cumulative variance plot
# Biplot or component loading visualization
# Scatter plot of data in PC space (first 2-3 components)
# Interpret what each component means: What real-world characteristic does it represent? Think ahead: How might these principal components help you predict your target variable in Phase 2?
#
# Critical Requirement: You must explain what you discovered in words a non-technical person would understand. What hidden groups or patterns exist in your data? Most importantly: How will these discoveries help you make better predictions?
#
# Important Note: If your initial unsupervised analysis doesn't reveal clear patterns, document this! Try different preprocessing (scaling, feature selection) or different methods. Sometimes discovering "no clear patterns" is valuable learning. Explain why patterns might not exist in your data and what this means for your predictive models.

# %% [markdown]
# I want to create a feature named something like a climate zone.<br>
#
# What is a climate zone?<br>
# Hot, humid.<br>
# Rainy, temperate.<br>
# Arid.<br>
#
# Climate zones based on temperature and precipitation were able to be created. They at least visually match Koeppen-Geiger zones. If time permits, a more rigorous match can be made.

# %% [markdown]
# What type of analysis can be conducted with the dataset that I have?<br>
#
# 1. albedo and sunlight
# 2. precipitation
# 3. rivers and estuaries
# 4. distance from coastline
# 5. existing infrastructure
# 6. population
# 7. wind
# 8. terrain
# 9. relative humidity
# 10. power plants
#
# Probably PCA? Is this an unsupervised or supervised learning task?<br>
#
# Seems like supervised, since there is a geographic label for every power plant? How, then, to make it unsupervised?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot
import os

population_df = pd.read_csv('data/population.csv', index_col=0)

print(f"{population_df.shape}")

sample_size = int(population_df.shape[0]*0.01//1)

print(f"Sample size to be used: {sample_size}")

population_sample = population_df.sample(sample_size)

population_sample.to_csv('population_sample.csv')
# Out:
# (11103610, 5)
# Sample size to be used: 111036

# %% [markdown]
# After some amount of analysis, the conclusion is that geography and atmospheric features don't contribute much to the types of power plants built. This analysis did not include seismic or natural disaster data.

# %% [markdown]
# <b>The Setup (30 seconds): What are you trying to predict and why does it matter?</b><br>
#
# The goal is to predict the potential capacity of a type of land or climate zone. For instance: if there are 5 main climate zones, does each have a different potential to generate electrical energy? If not this, then is there at least a pattern of the types of power plant built given a climate zone?<br>
#
# <b>The Feature Discovery (1 minute): What features did you discover using unsupervised learning? Show key visualizations</b><br>
#
# Unsupervised learning led to the development of climate zones, based mostly on monthly temperature and precipitation measurements. Temperature and precipitation measurements led to climate zones that closely matched the standard Koeppen-Geiger climate zones. The addition of measurements such as dew point and wind speed dramatically changed the climate zones.<br>
#
# <b>The Predictive Models (1 minute): How did those discovered features improve your prediction accuracy? Show before/after comparison</b><br>
#
# There wasn't a significant improvement in prediction accuracy with or without the climate zones. The features used to develop the climate zones were also used in predicting the type of power plant given atmospheric measurements.<br>
#
# <b>The Recommendation (30 seconds): What should someone do with your predictive insights?</b><br>
#
# The goal was to develop a model that could potentially assign a type of energy expectation based on geographic and atmospheric measurements. A type of land could potentially have an expected energy output. This hypothesis did not turn out to be true. The concentration of energy in high capacity power plants is mostly agnostic to geography.<br>
#
# The type of power plant can be predicted with approximately 60% accuracy. Common sense would deem that a hydroelectric dam has to be placed on a river, exactly on a body of water.<br>
#
# If I had to explain this to a nontechnical stakeholder, my explanation would be:<br>
#
#
#
#
#
#
# What exactly is it I'm trying to predict?
# I'm trying to assign an energy capacity to geographic archetypes, in other words, climate zones.
# Did I just not analyze the data correctly?

# %% [markdown]
# 80% -> 99% Complete Objectives:
#
# [ ] Name clusters.
#
# [ ] Fill in data quality issues.
#
# [ ] Write report.
#
# [ ] Complete visualizations for 1.
#
# [ ] PCA visuals.
#
# [ ] Population motivation.
